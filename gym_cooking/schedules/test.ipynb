# %%
import pandas as pd

# %%
df = pd.read_csv("./max_reward_schedule.csv")

df
# Out:
#     Unnamed: 0  Time  Machine                               Task  Points
# 0            0    11  agent-1                         Get(Plate)    0.00
# 1            1    22  agent-1                         Get(Plate)    0.00
# 2            2    33  agent-1                         Get(Plate)    0.00
# 3            3    44  agent-1                         Get(Plate)    0.00
# 4            4    55  agent-2                       Get(Lettuce)    0.00
# 5            5    55  agent-1                           Get(Bun)    0.00
# 6            6    66  agent-1                       Get(Lettuce)    0.00
# 7            7    77  agent-1                       Get(Lettuce)    0.00
# 8            8    95  agent-3                      Chop(Lettuce)    0.00
# 9            9   117  agent-2                      Chop(Lettuce)    0.00
# 10          10   127  agent-1                  Merge(Bun, Plate)    5.00
# 11          11   145  agent-4              Merge(Lettuce, Plate)    5.00
# ...

# %%
new_df = df['Task']
new_df.to_csv('task_list.csv', index= False)
